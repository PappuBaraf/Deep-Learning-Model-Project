# %% [markdown]
# <a href="https://colab.research.google.com/github/PappuBaraf/Deep-Learning-Model-Project/blob/main/Normal_Gradient_Descent_Type_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = [2, 3, 4, 5, 6, 7]
y = [15, 20, 35, 25, 28, 60]

w = 1.0
learning_rate = 0.1
batch_size = 3

print("Initial weight:", w)
print("=" * 50)




print("\nBATCH 1")

batch_x = x[0:3]
batch_y = y[0:3]

gradients = []

for xi, yi in zip(batch_x, batch_y):


    y_pred = w * xi

    gradient = (y_pred - yi) * xi

    gradients.append(gradient)

    print(f"x = {xi}, y = {yi}")
    print(f"Prediction = {y_pred}")
    print(f"Gradient = ({y_pred} - {yi}) * {xi} = {gradient}")
    print()

avg_gradient = sum(gradients) / batch_size

print("Gradients =", gradients)
print("Average Gradient =", avg_gradient)

w = w - learning_rate * avg_gradient

print("Updated Weight =", w)




print("\n" + "=" * 50)
print("BATCH 2")

batch_x = x[3:6]
batch_y = y[3:6]

gradients = []

for xi, yi in zip(batch_x, batch_y):


    y_pred = w * xi


    gradient = (y_pred - yi) * xi

    gradients.append(gradient)

    print(f"x = {xi}, y = {yi}")
    print(f"Prediction = {y_pred}")
    print(f"Gradient = ({y_pred} - {yi}) * {xi} = {gradient}")
    print()


avg_gradient = sum(gradients) / batch_size

print("Gradients =", gradients)
print("Average Gradient =", avg_gradient)


w = w - learning_rate * avg_gradient

print("Final Weight =", w)

print("\n" + "=" * 50)
print("FINAL RESULT")
print("Final weight =", w)
# Out:
# Initial weight: 1.0
# ...
#
# BATCH 1
# x = 2, y = 15
# Prediction = 2.0
# Gradient = (2.0 - 15) * 2 = -26.0
#
# x = 3, y = 20
# Prediction = 3.0
# Gradient = (3.0 - 20) * 3 = -51.0
#
# x = 4, y = 35
# Prediction = 4.0
# Gradient = (4.0 - 35) * 4 = -124.0
#
# Gradients = [-26.0, -51.0, -124.0]
# Average Gradient = -67.0
# Updated Weight = 7.7
#
# ...
# BATCH 2
# x = 5, y = 25
# Prediction = 38.5
# Gradient = (38.5 - 25) * 5 = 67.5
#
# x = 6, y = 28
# Prediction = 46.2
# Gradient = (46.2 - 28) * 6 = 109.20000000000002
#
# x = 7, y = 60
# Prediction = 53.9
# Gradient = (53.9 - 60) * 7 = -42.70000000000001
#
# Gradients = [67.5, 109.20000000000002, -42.70000000000001]
# Average Gradient = 44.666666666666664
# Final Weight = 3.2333333333333334
#
# ...
# FINAL RESULT
# Final weight = 3.2333333333333334
